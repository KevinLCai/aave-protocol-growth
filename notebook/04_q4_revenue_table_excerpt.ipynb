# %% [markdown]
# # Q4 Revenue Sensitivity Table — Accessibility Excerpt
#
# This notebook is **not new analysis**. It is an excerpt of Section 4.4 ("Sensitivity: bounding DAO revenue under HF and leverage uncertainty") from `04_q4_revenue_curve_configs.ipynb`, reproducing that section's "Combined sensitivity" table as selectable text/data rather than a screenshot image (the `HF`/`L` sensitivity sweep, sorted by DAO revenue).
#
# It exists solely so this table is accessible (screen readers / copy-paste / text search) when embedded in the Google Doc — for the underlying model, assumptions, and derivation, see Section 4.4 of the source notebook, `04_q4_revenue_curve_configs.ipynb`.

# %%
import pandas as pd

# Values copied verbatim from the "Combined sensitivity" table in
# 04_q4_revenue_curve_configs.ipynb (hurdle fixed, sorted by revenue).
sens_disp = pd.DataFrame([
    {"Scenario": "HF = 1.1",                    "HF (measured for base row, else formula-implied)": "1.1000", "Assumed L": "6.87x",  "Equilibrium U*": "62.17%", "Borrow rate r_b*": "2.76%", "DAO Revenue": "$4.29M", "Supply APY": "1.29%"},
    {"Scenario": "HF = 1.05",                   "HF (measured for base row, else formula-implied)": "1.0500", "Assumed L": "9.55x",  "Equilibrium U*": "70.87%", "Borrow rate r_b*": "3.15%", "DAO Revenue": "$5.58M", "Supply APY": "1.67%"},
    {"Scenario": "L = 10x",                     "HF (measured for base row, else formula-implied)": "1.0444", "Assumed L": "10.00x", "Equilibrium U*": "71.83%", "Borrow rate r_b*": "3.19%", "DAO Revenue": "$5.73M", "Supply APY": "1.72%"},
    {"Scenario": "L = 11.38x (base case)",       "HF (measured for base row, else formula-implied)": "1.0244", "Assumed L": "11.38x", "Equilibrium U*": "74.25%", "Borrow rate r_b*": "3.30%", "DAO Revenue": "$6.13M", "Supply APY": "1.84%"},
    {"Scenario": "L = 12x",                     "HF (measured for base row, else formula-implied)": "1.0255", "Assumed L": "12.00x", "Equilibrium U*": "75.13%", "Borrow rate r_b*": "3.34%", "DAO Revenue": "$6.27M", "Supply APY": "1.88%"},
    {"Scenario": "HF = 1.025",                  "HF (measured for base row, else formula-implied)": "1.0250", "Assumed L": "12.06x", "Equilibrium U*": "75.21%", "Borrow rate r_b*": "3.34%", "DAO Revenue": "$6.29M", "Supply APY": "1.89%"},
], index=[0, 1, 2, 3, 4, 5])

print("Combined sensitivity -- hurdle fixed, sorted by revenue (reproduced from 04_q4_revenue_curve_configs.ipynb)")
display(sens_disp)
# Out:
# Combined sensitivity -- hurdle fixed, sorted by revenue (reproduced from 04_q4_revenue_curve_configs.ipynb)
#                  Scenario HF (measured for base row, else formula-implied)  \
# 0                HF = 1.1                                           1.1000
# 1               HF = 1.05                                           1.0500
# 2                 L = 10x                                           1.0444
# 3  L = 11.38x (base case)                                           1.0244
# 4                 L = 12x                                           1.0255
# 5              HF = 1.025                                           1.0250
#
#   Assumed L Equilibrium U* Borrow rate r_b* DAO Revenue Supply APY
# 0     6.87x         62.17%            2.76%      $4.29M      1.29%
# 1     9.55x         70.87%            3.15%      $5.58M      1.67%
# 2    10.00x         71.83%            3.19%      $5.73M      1.72%
# 3    11.38x         74.25%            3.30%      $6.13M      1.84%
# ...
