# %% [markdown]
# # Q4 Curve Configurations Table — Accessibility Excerpt
#
# This notebook is **not new analysis**. It is an excerpt of Section 4.5 ("Three alternative curve configurations") from `04_q4_revenue_curve_configs.ipynb`, reproducing that section's table as selectable text/data rather than a screenshot image (status quo vs. three alternative `Uopt`/`slope1` configurations).
#
# It exists solely so this table is accessible (screen readers / copy-paste / text search) when embedded in the Google Doc — for the underlying model, assumptions, and derivation, see Section 4.5 of the source notebook, `04_q4_revenue_curve_configs.ipynb`.

# %%
import pandas as pd

# Values copied verbatim from the curve-configurations table in
# 04_q4_revenue_curve_configs.ipynb, Section 4.5.
disp = pd.DataFrame([
    {"Config": "Status quo",       "Uopt": "90%", "slope1": "4.0%", "Equilibrium U*": "74.25%", "Borrow rate r_b*": "3.30%", "DAO Revenue": "$6.13M", "Supply APY": "1.84%", "Curve branch": "below kink"},
    {"Config": "A: lower Uopt",    "Uopt": "80%", "slope1": "4.0%", "Equilibrium U*": "66.00%", "Borrow rate r_b*": "3.30%", "DAO Revenue": "$5.45M", "Supply APY": "1.63%", "Curve branch": "below kink"},
    {"Config": "B: raise slope1",  "Uopt": "90%", "slope1": "7.0%", "Equilibrium U*": "42.43%", "Borrow rate r_b*": "3.30%", "DAO Revenue": "$3.50M", "Supply APY": "1.05%", "Curve branch": "below kink"},
    {"Config": "C: moderate both", "Uopt": "85%", "slope1": "5.5%", "Equilibrium U*": "51.00%", "Borrow rate r_b*": "3.30%", "DAO Revenue": "$4.21M", "Supply APY": "1.26%", "Curve branch": "below kink"},
], index=[0, 1, 2, 3])

print("Curve configurations (reproduced from 04_q4_revenue_curve_configs.ipynb, Section 4.5)")
display(disp)
# Out:
# Curve configurations (reproduced from 04_q4_revenue_curve_configs.ipynb, Section 4.5)
#              Config Uopt slope1 Equilibrium U* Borrow rate r_b* DAO Revenue  \
# 0        Status quo  90%   4.0%         74.25%            3.30%      $6.13M
# 1     A: lower Uopt  80%   4.0%         66.00%            3.30%      $5.45M
# 2   B: raise slope1  90%   7.0%         42.43%            3.30%      $3.50M
# 3  C: moderate both  85%   5.5%         51.00%            3.30%      $4.21M
#
#   Supply APY Curve branch
# 0      1.84%   below kink
# 1      1.63%   below kink
# 2      1.05%   below kink
# 3      1.26%   below kink
